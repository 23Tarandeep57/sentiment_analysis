# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM, Concatenate, RepeatVector, Dot
from tensorflow.keras.layers import Input, Embedding, Bidirectional, Dropout
from tensorflow.keras.models import Model, Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
review_path = r'C:\Users\deept\OneDrive\Desktop\sentiment_analysis\datasets\yelp_dataset\yelp_academic_dataset_review.json'
size = 200000
review  = pd.read_json(review_path, lines = True, nrows = size)

# %%
review.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw
# 1  BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ
# 2  saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A
# 3  AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA
# 4  Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ
#
#    stars  useful  funny  cool  \
# 0      3       0      0     0
# 1      5       1      0     1
# 2      3       0      0     0
# 3      5       1      0     1
# 4      4       1      0     1
#
#                                                 text                date
# 0  If you decide to eat here, just be aware it is... 2018-07-07 22:09:11
# 1  I've taken a lot of spin classes over the year... 2012-01-03 15:28:18
# 2  Family diner. Had the buffet. Eclectic assortm... 2014-02-05 20:30:30
# 3  Wow!  Yummy, different,  delicious.   Our favo... 2015-01-04 00:01:03
# 4  Cute interior and owner (?) gave us tour of up... 2017-01-14 20:54:15

# %%
review.shape
# Out:
# (200000, 9)

# %%
df_review = review[['text', 'stars']]

# %%
df_review.head()
# Out:
#                                                 text  stars
# 0  If you decide to eat here, just be aware it is...      3
# 1  I've taken a lot of spin classes over the year...      5
# 2  Family diner. Had the buffet. Eclectic assortm...      3
# 3  Wow!  Yummy, different,  delicious.   Our favo...      5
# 4  Cute interior and owner (?) gave us tour of up...      4

# %%
df_review.info() #no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    200000 non-null  object
#  1   stars   200000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.1+ MB

# %%
df_review.describe()
# Out:
#                stars
# count  200000.000000
# mean        3.841425
# std         1.357044
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         5.000000
# max         5.000000

# %%
df_train, df_test = train_test_split(df_review, test_size = 0.02)

# %%
df_train.text.apply(lambda x: len(x.split(" "))).mean()
# Out:
# 102.36109183673469

# %%
tokenizer = Tokenizer(oov_token = "OOv")
tokenizer.fit_on_texts(df_train['text'])
word_indexs = tokenizer.word_index

# %%
word_indexs
# Out:
# {'OOv': 1,
#  'the': 2,
#  'and': 3,
#  'a': 4,
#  'i': 5,
#  'to': 6,
#  'was': 7,
#  'of': 8,
#  'is': 9,
#  'it': 10,
#  'for': 11,
#  'in': 12,
#  'my': 13,
#  'we': 14,
#  'with': 15,
#  'that': 16,
#  'but': 17,
#  'this': 18,
#  'they': 19,
#  'on': 20,
#  'you': 21,
#  'had': 22,
#  'have': 23,
#  'not': 24,
#  'were': 25,
#  'food': 26,
#  'so': 27,
#  'are': 28,
#  'good': 29,
#  'at': 30,
#  'place': 31,
#  'great': 32,
#  'be': 33,
#  'as': 34,
#  'very': 35,
#  'there': 36,
#  'all': 37,
#  'our': 38,
#  'out': 39,
#  'me': 40,
#  'if': 41,
#  'here': 42,
#  'service': 43,
#  'just': 44,
#  'like': 45,
#  'time': 46,
#  'one': 47,
#  'get': 48,
#  'from': 49,
#  'their': 50,
#  'back': 51,
#  'when': 52,
#  'or': 53,
#  'would': 54,
#  'go': 55,
#  "it's": 56,
#  'an': 57,
#  'up': 58,
#  'really': 59,
#  'which': 60,
#  'about': 61,
#  'will': 62,
#  'also': 63,
#  'been': 64,
#  'some': 65,
#  'what': 66,
#  'no': 67,
#  'only': 68,
#  'more': 69,
#  'your': 70,
#  'she': 71,
#  'nice': 72,
#  'can': 73,
#  'us': 74,
#  'got': 75,
#  'by': 76,
#  'he': 77,
#  'best': 78,
#  'because': 79,
#  'well': 80,
#  'them': 81,
#  'even': 82,
#  'other': 83,
#  'staff': 84,
#  'too': 85,
#  "don't": 86,
#  'ordered': 87,
#  'friendly': 88,
#  'love': 89,
#  "i've": 90,
#  'delicious': 91,
#  "i'm": 92,
#  'has': 93,
#  'after': 94,
#  'always': 95,
#  'order': 96,
#  'do': 97,
#  'restaurant': 98,
#  'little': 99,
#  'than': 100,
#  'chicken': 101,
#  'try': 102,
#  'first': 103,
#  'definitely': 104,
#  'came': 105,
#  'menu': 106,
#  'did': 107,
#  'went': 108,
#  "didn't": 109,
#  'could': 110,
#  'never': 111,
#  'amazing': 112,
#  'much': 113,
#  'over': 114,
#  'people': 115,
#  'new': 116,
#  'made': 117,
#  'again': 118,
#  'experience': 119,
#  'bar': 120,
#  'come': 121,
#  'make': 122,
#  'pretty': 123,
#  'wait': 124,
#  'two': 125,
#  'better': 126,
#  'day': 127,
#  'then': 128,
#  'her': 129,
#  'who': 130,
#  'fresh': 131,
#  'night': 132,
#  'way': 133,
#  'cheese': 134,
#  '2': 135,
#  'pizza': 136,
#  'going': 137,
#  'how': 138,
#  'off': 139,
#  'know': 140,
#  'recommend': 141,
#  'ever': 142,
#  'right': 143,
#  'everything': 144,
#  'before': 145,
#  'area': 146,
#  'while': 147,
#  '5': 148,
#  'any': 149,
#  'eat': 150,
#  'said': 151,
#  'down': 152,
#  'around': 153,
#  'want': 154,
#  'take': 155,
#  'sauce': 156,
#  'say': 157,
#  'lunch': 158,
#  'few': 159,
#  'sure': 160,
#  'room': 161,
#  'am': 162,
#  'think': 163,
#  'table': 164,
#  'still': 165,
#  'small': 166,
#  'minutes': 167,
#  '3': 168,
#  'next': 169,
#  'meal': 170,
#  'salad': 171,
#  'every': 172,
#  'bit': 173,
#  'took': 174,
#  'both': 175,
#  'times': 176,
#  'dinner': 177,
#  'give': 178,
#  'most': 179,
#  'now': 180,
#  'see': 181,
#  'many': 182,
#  "can't": 183,
#  'location': 184,
#  'since': 185,
#  'awesome': 186,
#  'excellent': 187,
#  'something': 188,
#  "wasn't": 189,
#  'drinks': 190,
#  'beer': 191,
#  'though': 192,
#  'coffee': 193,
#  'price': 194,
#  'find': 195,
#  'another': 196,
#  'lot': 197,
#  'bad': 198,
#  'being': 199,
#  'burger': 200,
#  'long': 201,
#  'last': 202,
#  'favorite': 203,
#  'worth': 204,
#  'atmosphere': 205,
#  'asked': 206,
#  'told': 207,
#  'tried': 208,
#  'breakfast': 209,
#  'hot': 210,
#  'work': 211,
#  'side': 212,
#  'fries': 213,
#  'where': 214,
#  'clean': 215,
#  'home': 216,
#  'super': 217,
#  'prices': 218,
#  'into': 219,
#  'his': 220,
#  '4': 221,
#  'looking': 222,
#  'happy': 223,
#  'feel': 224,
#  'sweet': 225,
#  'enough': 226,
#  'visit': 227,
#  'sandwich': 228,
#  'thing': 229,
#  'fried': 230,
#  'perfect': 231,
#  'wanted': 232,
#  'shrimp': 233,
#  'stars': 234,
#  'drink': 235,
#  'server': 236,
#  "you're": 237,
#  '10': 238,
#  'different': 239,
#  'big': 240,
#  'things': 241,
#  'quality': 242,
#  'need': 243,
#  'should': 244,
#  'taste': 245,
#  'check': 246,
#  'selection': 247,
#  '1': 248,
#  'hotel': 249,
#  'tasty': 250,
#  'flavor': 251,
#  'hour': 252,
#  'nothing': 253,
#  'away': 254,
#  'spot': 255,
#  'free': 256,
#  'places': 257,
#  'special': 258,
#  'found': 259,
#  'bread': 260,
#  'however': 261,
#  'its': 262,
#  'customer': 263,
#  'top': 264,
#  'store': 265,
#  'friends': 266,
#  'loved': 267,
#  'overall': 268,
#  'sushi': 269,
#  'years': 270,
#  'same': 271,
#  'full': 272,
#  'left': 273,
#  'once': 274,
#  'these': 275,
#  'meat': 276,
#  "that's": 277,
#  'dish': 278,
#  'large': 279,
#  'old': 280,
#  'ok': 281,
#  'wine': 282,
#  'highly': 283,
#  'kind': 284,
#  'each': 285,
#  'probably': 286,
#  'wonderful': 287,
#  'family': 288,
#  'enjoyed': 289,
#  'cream': 290,
#  'anything': 291,
#  'fun': 292,
#  'everyone': 293,
#  'look': 294,
#  'outside': 295,
#  'done': 296,
#  'friend': 297,
#  'waitress': 298,
#  'rice': 299,
#  'actually': 300,
#  'huge': 301,
#  'busy': 302,
#  'half': 303,
#  'coming': 304,
#  'ask': 305,
#  'husband': 306,
#  'why': 307,
#  'town': 308,
#  'inside': 309,
#  'thought': 310,
#  'else': 311,
#  'quite': 312,
#  'getting': 313,
#  'through': 314,
#  'soup': 315,
#  'fantastic': 316,
#  'maybe': 317,
#  "i'd": 318,
#  'pork': 319,
#  'disappointed': 320,
#  'without': 321,
#  'cooked': 322,
#  'parking': 323,
#  'options': 324,
#  'called': 325,
#  'decided': 326,
#  'used': 327,
#  'fish': 328,
#  'car': 329,
#  'open': 330,
#  "i'll": 331,
#  'enjoy': 332,
#  'ice': 333,
#  'served': 334,
#  'quick': 335,
#  'put': 336,
#  'line': 337,
#  'gave': 338,
#  'fast': 339,
#  'house': 340,
#  'hard': 341,
#  'tables': 342,
#  'helpful': 343,
#  'during': 344,
#  'him': 345,
#  'review': 346,
#  'must': 347,
#  'front': 348,
#  'spicy': 349,
#  'items': 350,
#  'far': 351,
#  'usually': 352,
#  'looked': 353,
#  'three': 354,
#  'high': 355,
#  'such': 356,
#  'local': 357,
#  'dishes': 358,
#  'business': 359,
#  'street': 360,
#  'city': 361,
#  'stop': 362,
#  'those': 363,
#  'absolutely': 364,
#  'manager': 365,
#  'steak': 366,
#  'tasted': 367,
#  'almost': 368,
#  'water': 369,
#  'reviews': 370,
#  'music': 371,
#  'stay': 372,
#  'let': 373,
#  'week': 374,
#  'decent': 375,
#  'having': 376,
#  'couple': 377,
#  'cool': 378,
#  'use': 379,
#  'restaurants': 380,
#  'waiting': 381,
#  'shop': 382,
#  'especially': 383,
#  'care': 384,
#  '30': 385,
#  'cold': 386,
#  'tacos': 387,
#  'beef': 388,
#  'eating': 389,
#  'least': 390,
#  'owner': 391,
#  'several': 392,
#  'star': 393,
#  "couldn't": 394,
#  'able': 395,
#  'seemed': 396,
#  'whole': 397,
#  'walk': 398,
#  'needed': 399,
#  'finally': 400,
#  'tell': 401,
#  'job': 402,
#  'extremely': 403,
#  "won't": 404,
#  'hours': 405,
#  '20': 406,
#  'live': 407,
#  'dining': 408,
#  'less': 409,
#  'trying': 410,
#  'return': 411,
#  'close': 412,
#  'part': 413,
#  'end': 414,
#  'wife': 415,
#  'money': 416,
#  'call': 417,
#  'someone': 418,
#  '6': 419,
#  'second': 420,
#  'makes': 421,
#  'bacon': 422,
#  'person': 423,
#  'door': 424,
#  'own': 425,
#  'attentive': 426,
#  'bring': 427,
#  'walked': 428,
#  'beautiful': 429,
#  'felt': 430,
#  'sit': 431,
#  'french': 432,
#  'wrong': 433,
#  'later': 434,
#  'pay': 435,
#  'dessert': 436,
#  'hair': 437,
#  'brought': 438,
#  'may': 439,
#  'brunch': 440,
#  'point': 441,
#  'waiter': 442,
#  'party': 443,
#  'today': 444,
#  'seating': 445,
#  'kids': 446,
#  'keep': 447,
#  '15': 448,
#  'cake': 449,
#  'crab': 450,
#  'year': 451,
#  'extra': 452,
#  'wish': 453,
#  'until': 454,
#  "there's": 455,
#  'arrived': 456,
#  'sat': 457,
#  'group': 458,
#  'days': 459,
#  'seated': 460,
#  'does': 461,
#  'plate': 462,
#  'tea': 463,
#  "isn't": 464,
#  'started': 465,
#  'oh': 466,
#  "doesn't": 467,
#  'instead': 468,
#  'waited': 469,
#  'red': 470,
#  'roll': 471,
#  'lots': 472,
#  'although': 473,
#  'either': 474,
#  'real': 475,
#  'style': 476,
#  'chocolate': 477,
#  'help': 478,
#  'course': 479,
#  'yet': 480,
#  'name': 481,
#  'trip': 482,
#  'st': 483,
#  'decor': 484,
#  'deal': 485,
#  'philly': 486,
#  'easy': 487,
#  'comes': 488,
#  'might': 489,
#  'anyone': 490,
#  'rolls': 491,
#  'wings': 492,
#  'bbq': 493,
#  'plus': 494,
#  'reasonable': 495,
#  'flavors': 496,
#  'cut': 497,
#  'fine': 498,
#  'liked': 499,
#  'perfectly': 500,
#  "they're": 501,
#  'leave': 502,
#  'stopped': 503,
#  'quickly': 504,
#  'size': 505,
#  'guy': 506,
#  'customers': 507,
#  'ate': 508,
#  'orleans': 509,
#  'chips': 510,
#  'portions': 511,
#  'working': 512,
#  'reason': 513,
#  'expect': 514,
#  'drive': 515,
#  'offer': 516,
#  'seems': 517,
#  'yelp': 518,
#  'yes': 519,
#  'fan': 520,
#  "wouldn't": 521,
#  'thai': 522,
#  'making': 523,
#  'warm': 524,
#  '8': 525,
#  'start': 526,
#  'burgers': 527,
#  'appetizer': 528,
#  'saw': 529,
#  'dry': 530,
#  'okay': 531,
#  'kitchen': 532,
#  'slow': 533,
#  'saturday': 534,
#  'regular': 535,
#  'late': 536,
#  'mexican': 537,
#  'eggs': 538,
#  'morning': 539,
#  'pick': 540,
#  'problem': 541,
#  '7': 542,
#  'amount': 543,
#  'space': 544,
#  'myself': 545,
#  'beers': 546,
#  'soon': 547,
#  'ago': 548,
#  'often': 549,
#  'stuff': 550,
#  'variety': 551,
#  'potato': 552,
#  'phone': 553,
#  'impressed': 554,
#  'early': 555,
#  'plenty': 556,
#  'expensive': 557,
#  'seafood': 558,
#  'thank': 559,
#  'counter': 560,
#  'sandwiches': 561,
#  'sunday': 562,
#  'average': 563,
#  'cheap': 564,
#  'short': 565,
#  'italian': 566,
#  'already': 567,
#  'grilled': 568,
#  'priced': 569,
#  'tour': 570,
#  'ended': 571,
#  'green': 572,
#  'past': 573,
#  'doing': 574,
#  'rude': 575,
#  'yummy': 576,
#  'weekend': 577,
#  'fact': 578,
#  'beans': 579,
#  'comfortable': 580,
#  'egg': 581,
#  'given': 582,
#  'ready': 583,
#  'white': 584,
#  'light': 585,
#  'guys': 586,
#  'bowl': 587,
#  'etc': 588,
#  'list': 589,
#  'entire': 590,
#  'glad': 591,
#  'sitting': 592,
#  'worst': 593,
#  'serve': 594,
#  'available': 595,
#  'pasta': 596,
#  'portion': 597,
#  'bartender': 598,
#  'recommended': 599,
#  'terrible': 600,
#  'unique': 601,
#  'rooms': 602,
#  'authentic': 603,
#  'seem': 604,
#  'buy': 605,
#  'ordering': 606,
#  'choice': 607,
#  'twice': 608,
#  'flavorful': 609,
#  'under': 610,
#  'between': 611,
#  'nashville': 612,
#  'evening': 613,
#  'needs': 614,
#  'run': 615,
#  'offered': 616,
#  'walking': 617,
#  'received': 618,
#  'gets': 619,
#  'ingredients': 620,
#  'mind': 621,
#  'looks': 622,
#  'change': 623,
#  'bite': 624,
#  'life': 625,
#  'employees': 626,
#  'potatoes': 627,
#  'set': 628,
#  'four': 629,
#  'show': 630,
#  'dog': 631,
#  'guess': 632,
#  'professional': 633,
#  'pleasant': 634,
#  '50': 635,
#  'tip': 636,
#  'believe': 637,
#  'main': 638,
#  'rather': 639,
#  'crispy': 640,
#  'servers': 641,
#  'chef': 642,
#  'cafe': 643,
#  'others': 644,
#  'add': 645,
#  'seen': 646,
#  'near': 647,
#  'prepared': 648,
#  'floor': 649,
#  'paid': 650,
#  'itself': 651,
#  'grits': 652,
#  'horrible': 653,
#  'oysters': 654,
#  'across': 655,
#  'heard': 656,
#  'cute': 657,
#  'along': 658,
#  'kept': 659,
#  'recently': 660,
#  "haven't": 661,
#  'toast': 662,
#  'butter': 663,
#  'taco': 664,
#  'hands': 665,
#  'simple': 666,
#  'mac': 667,
#  'totally': 668,
#  'thanks': 669,
#  'buffet': 670,
#  "you'll": 671,
#  'friday': 672,
#  'sometimes': 673,
#  'salsa': 674,
#  'behind': 675,
#  'garlic': 676,
#  'knew': 677,
#  'expected': 678,
#  'taking': 679,
#  'completely': 680,
#  'neighborhood': 681,
#  'eaten': 682,
#  'man': 683,
#  'packed': 684,
#  'orders': 685,
#  'choose': 686,
#  'bill': 687,
#  'five': 688,
#  'rest': 689,
#  'glass': 690,
#  'charge': 691,
#  'bland': 692,
#  'visiting': 693,
#  'pancakes': 694,
#  'please': 695,
#  'meals': 696,
#  'crowded': 697,
#  'ambiance': 698,
#  'birthday': 699,
#  'hit': 700,
#  'boyfriend': 701,
#  'sausage': 702,
#  'delivery': 703,
#  'remember': 704,
#  'surprised': 705,
#  'gone': 706,
#  'downtown': 707,
#  'black': 708,
#  'park': 709,
#  'hope': 710,
#  'type': 711,
#  'wow': 712,
#  'due': 713,
#  'interesting': 714,
#  'months': 715,
#  'specials': 716,
#  'seriously': 717,
#  'chinese': 718,
#  'company': 719,
#  "weren't": 720,
#  'option': 721,
#  'literally': 722,
#  'pricey': 723,
#  'based': 724,
#  'loud': 725,
#  'immediately': 726,
#  'stayed': 727,
#  'choices': 728,
#  'unfortunately': 729,
#  'within': 730,
#  'hand': 731,
#  'together': 732,
#  'game': 733,
#  '9': 734,
#  '12': 735,
#  'date': 736,
#  'reservation': 737,
#  'desk': 738,
#  'appointment': 739,
#  'outstanding': 740,
#  'opened': 741,
#  'donuts': 742,
#  'crust': 743,
#  'world': 744,
#  'cost': 745,
#  'cup': 746,
#  'appetizers': 747,
#  'card': 748,
#  'incredible': 749,
#  'empty': 750,
#  'wedding': 751,
#  'salon': 752,
#  'oil': 753,
#  'understand': 754,
#  'minute': 755,
#  'patio': 756,
#  'salmon': 757,
#  'forward': 758,
#  'vegetarian': 759,
#  'exactly': 760,
#  'added': 761,
#  'issue': 762,
#  'truly': 763,
#  'lady': 764,
#  'nola': 765,
#  'soft': 766,
#  'giving': 767,
#  'moved': 768,
#  'watch': 769,
#  'tender': 770,
#  'girl': 771,
#  "we've": 772,
#  'view': 773,
#  'taken': 774,
#  'honestly': 775,
#  'sides': 776,
#  'upon': 777,
#  'yourself': 778,
#  'tomato': 779,
#  'knowledgeable': 780,
#  'plates': 781,
#  'excited': 782,
#  'building': 783,
#  'including': 784,
#  'located': 785,
#  'center': 786,
#  'weeks': 787,
#  'pieces': 788,
#  'poor': 789,
#  'seat': 790,
#  'onion': 791,
#  'entrees': 792,
#  'solid': 793,
#  'lovely': 794,
#  'homemade': 795,
#  'worked': 796,
#  '00': 797,
#  'number': 798,
#  'vibe': 799,
#  'noodles': 800,
#  'visited': 801,
#  'salads': 802,
#  'feeling': 803,
#  'read': 804,
#  'miss': 805,
#  'above': 806,
#  'mean': 807,
#  'corn': 808,
#  'saying': 809,
#  'pie': 810,
#  'ones': 811,
#  'grab': 812,
#  'talk': 813,
#  'anywhere': 814,
#  'hungry': 815,
#  'bought': 816,
#  'tasting': 817,
#  'longer': 818,
#  'outdoor': 819,
#  'month': 820,
#  'medium': 821,
#  'head': 822,
#  'louis': 823,
#  'afternoon': 824,
#  'toppings': 825,
#  'entree': 826,
#  'level': 827,
#  'ribs': 828,
#  "aren't": 829,
#  'pho': 830,
#  'filled': 831,
#  '45': 832,
#  'sign': 833,
#  'pool': 834,
#  'pulled': 835,
#  'fair': 836,
#  'massage': 837,
#  'checked': 838,
#  'cocktails': 839,
#  'baked': 840,
#  'low': 841,
#  'reno': 842,
#  'greeted': 843,
#  'owners': 844,
#  'treat': 845,
#  'helped': 846,
#  'cannot': 847,
#  'spend': 848,
#  'curry': 849,
#  'south': 850,
#  'noticed': 851,
#  'dirty': 852,
#  'simply': 853,
#  'salty': 854,
#  'indian': 855,
#  'seasoned': 856,
#  'idea': 857,
#  'chance': 858,
#  'burrito': 859,
#  'piece': 860,
#  'gem': 861,
#  '25': 862,
#  'certainly': 863,
#  'vegan': 864,
#  'hear': 865,
#  'hostess': 866,
#  'yum': 867,
#  'attention': 868,
#  'spent': 869,
#  'cash': 870,
#  'lamb': 871,
#  'bathroom': 872,
#  'veggie': 873,
#  'closed': 874,
#  'standard': 875,
#  'market': 876,
#  'online': 877,
#  'onions': 878,
#  'tastes': 879,
#  'crowd': 880,
#  'establishment': 881,
#  'mouth': 882,
#  'thin': 883,
#  'tampa': 884,
#  'sorry': 885,
#  'frozen': 886,
#  'share': 887,
#  'beyond': 888,
#  'lobster': 889,
#  'wall': 890,
#  'turned': 891,
#  'healthy': 892,
#  'filling': 893,
#  'office': 894,
#  'duck': 895,
#  'takes': 896,
#  'stuffed': 897,
#  'bed': 898,
#  'cocktail': 899,
#  'event': 900,
#  'serving': 901,
#  'management': 902,
#  'mention': 903,
#  'goes': 904,
#  'typical': 905,
#  'tuna': 906,
#  'talking': 907,
#  'disappointing': 908,
#  'move': 909,
#  'finish': 910,
#  'overpriced': 911,
#  'non': 912,
#  'bottle': 913,
#  'plan': 914,
#  'incredibly': 915,
#  'mix': 916,
#  'anyway': 917,
#  'slightly': 918,
#  'basically': 919,
#  'tiny': 920,
#  'note': 921,
#  'dressing': 922,
#  'finished': 923,
#  'nails': 924,
#  'veggies': 925,
#  'middle': 926,
#  'case': 927,
#  'casual': 928,
#  "we're": 929,
#  'true': 930,
#  'fairly': 931,
#  'questions': 932,
#  'mine': 933,
#  'w': 934,
#  'tucson': 935,
#  'accommodating': 936,
#  'single': 937,
#  'crazy': 938,
#  'fruit': 939,
#  '11': 940,
#  'daughter': 941,
#  'paying': 942,
#  'sauces': 943,
#  'complaint': 944,
#  'cook': 945,
#  'picked': 946,
#  'unless': 947,
#  'mediocre': 948,
#  'joint': 949,
#  'n': 950,
#  'blue': 951,
#  'young': 952,
#  'fix': 953,
#  'mixed': 954,
#  'woman': 955,
#  'tonight': 956,
#  'returning': 957,
#  'easily': 958,
#  'gotten': 959,
#  'changed': 960,
#  'addition': 961,
#  'fabulous': 962,
#  'happened': 963,
#  'value': 964,
#  'split': 965,
#  'shared': 966,
#  'awful': 967,
#  'limited': 968,
#  'corner': 969,
#  'touch': 970,
#  'pleased': 971,
#  'play': 972,
#  'philadelphia': 973,
#  'stand': 974,
#  'class': 975,
#  'mom': 976,
#  'la': 977,
#  'mall': 978,
#  'son': 979,
#  'write': 980,
#  'mostly': 981,
#  'creamy': 982,
#  'credit': 983,
#  'spice': 984,
#  'welcoming': 985,
#  'quiet': 986,
#  'shopping': 987,
#  'window': 988,
#  'box': 989,
#  'chain': 990,
#  'santa': 991,
#  'die': 992,
#  'says': 993,
#  'thick': 994,
#  'total': 995,
#  'guests': 996,
#  'dark': 997,
#  'salt': 998,
#  'chose': 999,
#  'somewhere': 1000,
#  ...}

# %%
vocab_size = len(word_indexs)

# %%
tokenized_train = tokenizer.texts_to_sequences(df_train['text'])
tokenized_test = tokenizer.texts_to_sequences(df_test['text'])

# %%
padding_type = 'post'
truncating_type = 'post'
Tx = 110 # since avg words in sentence is 102.38

# %%
x_train = pad_sequences(tokenized_train, maxlen = Tx, padding = padding_type, truncating = truncating_type)
x_test = pad_sequences(tokenized_test, maxlen = Tx, padding = padding_type, truncating = truncating_type)
y_train = df_train['stars']
y_test = df_test['stars']

# %%
yoh_train = pd.get_dummies(y_train, dtype = 'int32')
yoh_test = pd.get_dummies(y_test, dtype = 'int32')

# %%
print(f"shape of x_train: {x_train.shape}")
print(f"shape of x_test: {x_test.shape}")
print(f"shape of y_train: {y_train.shape}")
print(f"shape of y_test: {y_test.shape}")
print(f"shape of yoh_train: {yoh_train.shape}")
print(f"shape of yoh_test: {yoh_test.shape}")
# Out:
# shape of x_train: (196000, 110)
# shape of x_test: (4000, 110)
# shape of y_train: (196000,)
# shape of y_test: (4000,)
# shape of yoh_train: (196000, 5)
# shape of yoh_test: (4000, 5)

# %%
x_train
# Out:
# array([[ 187,   26,  190, ...,    0,    0,    0],
#        [  27,    5, 5437, ...,  836,   27, 1121],
#        [  73,    5,  178, ...,    0,    0,    0],
#        ...,
#        [  61,  135,  715, ...,   30,  248, 9677],
#        [1962,  251,   35, ...,    0,    0,    0],
#        [ 729,    5,  847, ...,    0,    0,    0]])

# %% [markdown]
# ## Predicting number of Stars

# %%
n_a = 32
n_s = 64
embed_size = 128
repeator = RepeatVector(Tx)
concatenator = Concatenate(axis = -1)
densor1 = Dense(32, activation = 'relu')
dotor = Dot(axes = 1)

# %%
def one_step_attention(a, s_prev):
    s_prev = repeator(s_prev)
    cat = concatenator([a, s_prev])
    e = densor1(cat)
    drop_out = Dropout(.4)(e)
    alphas = tf.keras.activations.softmax(drop_out, axis = -1)
    context = dotor([alphas, a])
    
    return context

# %%
post_LSTM_cell = LSTM(n_s, return_state = True)
output_layer_star = Dense(5, activation = 'softmax')

# %%
def modelf(Tx, n_a, n_s, vacab_size, embed_size):
    sequence_input = Input(shape = (Tx, ), dtype = 'int32')
    embedded_sequences = Embedding(vocab_size+1, embed_size)(sequence_input)

    s0 = Input(shape = (n_s, ), name = 's0')
    c0 = Input(shape = (n_s, ), name = 'c0')
    s = s0
    c = c0

    a = Bidirectional(LSTM(units = n_a, return_sequences = True))(embedded_sequences)

    context = one_step_attention(a, s)
    _, s, c = post_LSTM_cell(context, initial_state = [s, c])
    out = output_layer_star(s)
    model = Model(inputs = [sequence_input, s0, c0], outputs = out)
    return model

# %%
model1 = modelf(Tx, n_a, n_s, vocab_size, embed_size)

# %%
model1.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 110)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_2 (Embedding)       │ (None, 110, 128)          │      12,951,936 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ s0 (InputLayer)               │ (None, 64)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional_2               │ (None, 110, 64)           │          41,216 │ embedding_2[0][0]          │
# │ (Bidirectional)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ repeat_vector (RepeatVector)  │ (None, 110, 64)           │               0 │ s0[0][0]                   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 110, 128)          │               0 │ bidirectional_2[0][0],     │
# │                               │                           │                 │ repeat_vector[2][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 110, 32)           │           4,128 │ concatenate[2][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 110, 32)           │               0 │ dense[2][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ softmax_2 (Softmax)           │ (None, 110, 32)           │               0 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dot (Dot)                     │ (None, 32, 64)            │               0 │ softmax_2[0][0],           │
# │                               │                           │                 │ bidirectional_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ c0 (InputLayer)               │ (None, 64)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ [(None, 64), (None, 64),  │          33,024 │ dot[2][0], s0[0][0],       │
# │                               │ (None, 64)]               │                 │ c0[0][0]                   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 5)                 │             325 │ lstm[2][1]                 │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 13,030,629 (49.71 MB)
#  Trainable params: 13,030,629 (49.71 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model1.compile(loss = 'CategoricalCrossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
s0 = np.zeros((len(x_train), n_s))
c0 = np.zeros((len(x_train), n_s))
s0_test = np.zeros((len(x_test), n_s))
c0_test = np.zeros((len(x_test), n_s))

# %%
BATCH_SIZE = 100
EPOCHS = 3
history = model1.fit([x_train, s0,c0],yoh_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=([x_test, s0_test, c0_test], yoh_test))
# Out:
# Epoch 1/3
# 1960/1960 ━━━━━━━━━━━━━━━━━━━━ 251s 125ms/step - accuracy: 0.5980 - loss: 0.9428 - val_accuracy: 0.6645 - val_loss: 0.7857
# Epoch 2/3
# 1960/1960 ━━━━━━━━━━━━━━━━━━━━ 245s 125ms/step - accuracy: 0.6939 - loss: 0.7152 - val_accuracy: 0.6660 - val_loss: 0.7996
# Epoch 3/3
# 1960/1960 ━━━━━━━━━━━━━━━━━━━━ 246s 126ms/step - accuracy: 0.7435 - loss: 0.6104 - val_accuracy: 0.6553 - val_loss: 0.8302

# %%
y_pred = model1.predict([x_test, s0_test, c0_test])
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step

# %%
y_star = np.argmax(y_pred, axis = 1) + 1
y_star
# Out:
# array([5, 4, 4, ..., 5, 5, 5], dtype=int64)

# %%
sum = np.sum(y_star == y_test)

# %%
acc = sum/len(y_test)
acc
# Out:
# 0.65525

# %%
plt.hist(y_star)
# Out:
# (array([ 516.,    0.,  288.,    0.,    0.,  275.,    0.,  961.,    0.,
#         1960.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(y_test)
# Out:
# (array([ 449.,    0.,  339.,    0.,    0.,  439.,    0., 1010.,    0.,
#         1763.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Binary classification (positive or negative)

# %%
y_train_sentiment = np.where(y_train > 3, 1, 0)
y_test_sentiment = np.where(y_test > 3, 1, 0)

# %%
output_layer_sentiment = Dense(1, activation = 'sigmoid')

# %%
def modelf_2(Tx, n_a, n_s, vacab_size, embed_size):
    sequence_input = Input(shape = (Tx, ), dtype = 'int32')
    embedded_sequences = Embedding(vocab_size+1, embed_size)(sequence_input)

    s0 = Input(shape = (n_s, ), name = 's0')
    c0 = Input(shape = (n_s, ), name = 'c0')
    s = s0
    c = c0

    a = Bidirectional(LSTM(units = n_a, return_sequences = True))(embedded_sequences)

    context = one_step_attention(a, s)
    _, s, c = post_LSTM_cell(context, initial_state = [s, c])
    out = output_layer_sentiment(s)
    model = Model(inputs = [sequence_input, s0, c0], outputs = out)
    return model

# %%
model2 = modelf_2(Tx, n_a, n_s, vocab_size, embed_size)

# %%
model2.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model2.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)    │ (None, 110)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_1 (Embedding)       │ (None, 110, 128)          │      12,951,936 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ s0 (InputLayer)               │ (None, 64)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bidirectional_1               │ (None, 110, 64)           │          41,216 │ embedding_1[0][0]          │
# │ (Bidirectional)               │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ repeat_vector (RepeatVector)  │ (None, 110, 64)           │               0 │ s0[0][0]                   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 110, 128)          │               0 │ bidirectional_1[0][0],     │
# │                               │                           │                 │ repeat_vector[1][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 110, 32)           │           4,128 │ concatenate[1][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 110, 32)           │               0 │ dense[1][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ softmax_1 (Softmax)           │ (None, 110, 32)           │               0 │ dropout_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dot (Dot)                     │ (None, 32, 64)            │               0 │ softmax_1[0][0],           │
# │                               │                           │                 │ bidirectional_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ c0 (InputLayer)               │ (None, 64)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ [(None, 64), (None, 64),  │          33,024 │ dot[1][0], s0[0][0],       │
# │                               │ (None, 64)]               │                 │ c0[0][0]                   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 1)                 │              65 │ lstm[1][1]                 │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 13,030,369 (49.71 MB)
#  Trainable params: 13,030,369 (49.71 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
BATCH_SIZE = 100
EPOCHS = 3
history = model2.fit([x_train, s0,c0],y_train_sentiment,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_data=([x_test, s0_test, c0_test], y_test_sentiment))
# Out:
# Epoch 1/3
# 1960/1960 ━━━━━━━━━━━━━━━━━━━━ 258s 129ms/step - accuracy: 0.8562 - loss: 0.3298 - val_accuracy: 0.9040 - val_loss: 0.2226
# Epoch 2/3
# 1960/1960 ━━━━━━━━━━━━━━━━━━━━ 249s 127ms/step - accuracy: 0.9241 - loss: 0.1901 - val_accuracy: 0.9105 - val_loss: 0.2309
# Epoch 3/3
# 1960/1960 ━━━━━━━━━━━━━━━━━━━━ 250s 128ms/step - accuracy: 0.9443 - loss: 0.1410 - val_accuracy: 0.9010 - val_loss: 0.2628

# %%
y_pred = model2.predict([x_test, s0_test, c0_test])
prediction = (y_pred >= 0.5)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step

# %%
plt.hist(prediction.astype(float))
plt.title("y_pred")
plt.show()

plt.hist(y_test_sentiment)
plt.title("y_test")
plt.show()

# %%
sum = np.sum(y_test_sentiment.astype(int).reshape(-1,1) == prediction.astype(int).reshape(-1,1))

# %%
acc = sum/len(prediction)
acc
# Out:
# 0.901
